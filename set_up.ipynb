# %%
# pip install modal
# pip install jupyter
# %pip install -r requirements.txt

# python3 -m modal setup

# conda activate electiont

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: jupyter in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: modal in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.62.81)
# Requirement already satisfied: pandas in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: numpy in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.8.4)
# Collecting scikit-learn (from -r requirements.txt (line 6))
#   Downloading scikit_learn-1.4.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting scipy (from -r requirements.txt (line 7))
#   Downloading scipy-1.13.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: notebook in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (7.1.3)
# Requirement already satisfied: qtconsole in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (5.5.1)
# Requirement already satisfied: jupyter-console in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (7.16.3)
# Requirement already satisfied: ipykernel in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (6.29.3)
# Requirement already satisfied: ipywidgets in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.2)
# Requirement already satisfied: aiohttp in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (3.9.5)
# Requirement already satisfied: aiostream~=0.5.2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: certifi in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (2024.2.2)
# Requirement already satisfied: click>=8.1.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: fastapi in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.110.1)
# Requirement already satisfied: grpclib==0.4.7 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.4.7)
# Requirement already satisfied: protobuf!=4.24.0,<6.0,>=3.19 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (5.26.1)
# Requirement already satisfied: rich>=12.0.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (13.7.1)
# Requirement already satisfied: synchronicity~=0.6.6 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.6.7)
# Requirement already satisfied: toml in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: typer~=0.9.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.9.4)
# Requirement already satisfied: types-certifi in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (2021.10.8.3)
# Requirement already satisfied: types-toml in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.10.8.20240310)
# Requirement already satisfied: watchfiles in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: typing-extensions~=4.6 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from modal->-r requirements.txt (line 2)) (4.11.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from grpclib==0.4.7->modal->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: multidict in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from grpclib==0.4.7->modal->-r requirements.txt (line 2)) (6.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (24.0)
# Requirement already satisfied: pillow>=8 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (3.1.2)
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements.txt (line 6))
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->-r requirements.txt (line 6))
#   Using cached threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from rich>=12.0.0->modal->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from rich>=12.0.0->modal->-r requirements.txt (line 2)) (2.17.2)
# Requirement already satisfied: sigtools==4.0.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from synchronicity~=0.6.6->modal->-r requirements.txt (line 2)) (4.0.1)
# Requirement already satisfied: attrs in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from sigtools==4.0.1->synchronicity~=0.6.6->modal->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from aiohttp->modal->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from aiohttp->modal->-r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from aiohttp->modal->-r requirements.txt (line 2)) (1.9.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from fastapi->modal->-r requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from fastapi->modal->-r requirements.txt (line 2)) (0.37.2)
# Requirement already satisfied: appnope in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.22.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (26.0.0)
# Requirement already satisfied: tornado>=6.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 1)) (3.0.42)
# Requirement already satisfied: beautifulsoup4 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (2.26.0)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (4.1.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from qtconsole->jupyter->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: anyio>=3.0.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from watchfiles->modal->-r requirements.txt (line 2)) (4.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from anyio>=3.0.0->watchfiles->modal->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from anyio>=3.0.0->watchfiles->modal->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: webencodings in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: decorator in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: stack-data in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (4.21.1)
# Requirement already satisfied: requests>=2.31 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: wcwidth in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->modal->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->modal->-r requirements.txt (line 2)) (2.18.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: fqdn in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.4)
# Requirement already satisfied: uri-template in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pycparser in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/kaylahuang/opt/anaconda3/envs/electiont/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.9.0.20240316)
# Downloading scikit_learn-1.4.2-cp312-cp312-macosx_12_0_arm64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 15.6 MB/s eta 0:00:0000:010:01
# Downloading scipy-1.13.0-cp312-cp312-macosx_12_0_arm64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 18.3 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 16.9 MB/s eta 0:00:00
# Using cached threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import modal

stub = modal.Stub("example-get-started")


@stub.function()
def square(x):
    print("This code is running on a remote worker!")
    return x**2


@stub.local_entrypoint()
def main():
    print("the square is", square.remote(42))

# %%
# %cat > get_started.py 
# %modal run get_started.py
# Out:
# ^C

# %%
import pandas as pd 

df = pd.read_csv("truth_seeker.csv")
df.head()
# Out:
#    Unnamed: 0      author                                          statement  \
# 0           0  D.L. Davis  End of eviction moratorium means millions of A...
# 1           1  D.L. Davis  End of eviction moratorium means millions of A...
# 2           2  D.L. Davis  End of eviction moratorium means millions of A...
# 3           3  D.L. Davis  End of eviction moratorium means millions of A...
# 4           4  D.L. Davis  End of eviction moratorium means millions of A...
#
#    target  BinaryNumTarget                 manual_keywords  \
# 0    True              1.0  Americans, eviction moratorium
# 1    True              1.0  Americans, eviction moratorium
# 2    True              1.0  Americans, eviction moratorium
# 3    True              1.0  Americans, eviction moratorium
# 4    True              1.0  Americans, eviction moratorium
#
#                                                tweet 5_label_majority_answer  \
# 0  @POTUS Biden Blunders - 6 Month Update\n\nInfl...            Mostly Agree
# 1  @S0SickRick @Stairmaster_ @6d6f636869 Not as m...             NO MAJORITY
# 2  THE SUPREME COURT is siding with super rich pr...                   Agree
# 3  @POTUS Biden Blunders\n\nBroken campaign promi...            Mostly Agree
# 4  @OhComfy I agree. The confluence of events rig...                   Agree
#
#   3_label_majority_answer
# 0                   Agree
# 1                   Agree
# 2                   Agree
# 3                   Agree
# 4                   Agree
